# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('final_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      Date  stid  Daily_Production  \
# 0           0  19940101  ACME          12384900
# 1           1  19940102  ACME          11908500
# 2           2  19940103  ACME          12470700
# 3           3  19940104  ACME          12725400
# 4           4  19940105  ACME          10894800
#
#                                        new_distances  min_dist_node  \
# 0  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 1  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 2  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 3  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 4  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
#
#                     join  tcolc_eatm_0  ulwrf_tatm_0  dlwrf_sfc_0  ...  \
# 0  19940101(35.0, 262.0)      0.002298     254.38380    258.64188  ...
# 1  19940102(35.0, 262.0)      0.069067     231.38722    279.48965  ...
# ...

# %%
df.drop('Unnamed: 0',axis=1).head()
# Out:
#        Date  stid  Daily_Production  \
# 0  19940101  ACME          12384900
# 1  19940102  ACME          11908500
# 2  19940103  ACME          12470700
# 3  19940104  ACME          12725400
# 4  19940105  ACME          10894800
#
#                                        new_distances  min_dist_node  \
# 0  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 1  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 2  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 3  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 4  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
#
#                     join  tcolc_eatm_0  ulwrf_tatm_0  dlwrf_sfc_0  tmp_sfc_0  \
# 0  19940101(35.0, 262.0)      0.002298     254.38380    258.64188  282.54855
# 1  19940102(35.0, 262.0)      0.069067     231.38722    279.48965  282.33215
# 2  19940103(35.0, 262.0)      0.001782     241.27985    227.04659  277.42630
# ...

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#           Unnamed: 0  stid  Daily_Production  \
# Date
# 19940101           0  ACME          12384900
# 19940102           1  ACME          11908500
# 19940103           2  ACME          12470700
# 19940104           3  ACME          12725400
# 19940105           4  ACME          10894800
#
#                                               new_distances  min_dist_node  \
# Date
# 19940101  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940102  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940103  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940104  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940105  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
#
#                            join  tcolc_eatm_0  ulwrf_tatm_0  dlwrf_sfc_0  \
# Date
# 19940101  19940101(35.0, 262.0)      0.002298     254.38380    258.64188
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 501074 entries, 19940101 to 20071231
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        501074 non-null  int64
#  1   stid              501074 non-null  object
#  2   Daily_Production  501074 non-null  int64
#  3   new_distances     501074 non-null  object
#  4   min_dist_node     501074 non-null  object
#  5   join              501074 non-null  object
#  6   tcolc_eatm_0      501074 non-null  float64
#  7   ulwrf_tatm_0      501074 non-null  float64
#  8   dlwrf_sfc_0       501074 non-null  float64
#  9   tmp_sfc_0         501074 non-null  float64
#  10  tcdc_eatm_0       501074 non-null  float64
#  11  dswrf_sfc_0       501074 non-null  float64
#  12  tmax_2m_0         501074 non-null  float64
#  13  tmin_2m_0         501074 non-null  float64
#  14  pwat_eatm_0       501074 non-null  float64
# ...

# %%
df.isnull()
# Out:
#           Unnamed: 0   stid  Daily_Production  new_distances  min_dist_node  \
# Date
# 19940101       False  False             False          False          False
# 19940102       False  False             False          False          False
# 19940103       False  False             False          False          False
# 19940104       False  False             False          False          False
# 19940105       False  False             False          False          False
# ...              ...    ...               ...            ...            ...
# 20071227       False  False             False          False          False
# 20071228       False  False             False          False          False
# 20071229       False  False             False          False          False
# 20071230       False  False             False          False          False
# 20071231       False  False             False          False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# stid                0
# Daily_Production    0
# new_distances       0
# min_dist_node       0
# join                0
# tcolc_eatm_0        0
# ulwrf_tatm_0        0
# dlwrf_sfc_0         0
# tmp_sfc_0           0
# tcdc_eatm_0         0
# dswrf_sfc_0         0
# tmax_2m_0           0
# tmin_2m_0           0
# pwat_eatm_0         0
# uswrf_sfc_0         0
# spfh_2m_0           0
# ulwrf_sfc_0         0
# tmp_2m_0            0
# apcp_sfc_0          0
# pres_msl_0          0
# dtype: int64

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_22508\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.corr()['Daily_Production'].sort_values()
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_22508\4203343499.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Daily_Production'].sort_values()
# tcdc_eatm_0        -0.467513
# tcolc_eatm_0       -0.467079
# apcp_sfc_0         -0.294471
# pres_msl_0         -0.203145
# Unnamed: 0         -0.021058
# pwat_eatm_0         0.224853
# dlwrf_sfc_0         0.327998
# spfh_2m_0           0.395207
# tmin_2m_0           0.564548
# tmp_2m_0            0.612552
# tmax_2m_0           0.612744
# ulwrf_sfc_0         0.623809
# tmp_sfc_0           0.634328
# ulwrf_tatm_0        0.648427
# uswrf_sfc_0         0.783920
# dswrf_sfc_0         0.875885
# Daily_Production    1.000000
# Name: Daily_Production, dtype: float64

# %%
sns.distplot(df['Daily_Production'])
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_22508\3748308015.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Daily_Production'])
# <Axes: xlabel='Daily_Production', ylabel='Density'>

# %%
df.head()
# Out:
#           Unnamed: 0  stid  Daily_Production  \
# Date
# 19940101           0  ACME          12384900
# 19940102           1  ACME          11908500
# 19940103           2  ACME          12470700
# 19940104           3  ACME          12725400
# 19940105           4  ACME          10894800
#
#                                               new_distances  min_dist_node  \
# Date
# 19940101  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940102  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940103  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940104  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940105  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
#
#                            join  tcolc_eatm_0  ulwrf_tatm_0  dlwrf_sfc_0  \
# Date
# 19940101  19940101(35.0, 262.0)      0.002298     254.38380    258.64188
# ...

# %%
sns.scatterplot(x='dswrf_sfc_0',y='Daily_Production',data=df)
# Out:
# <Axes: xlabel='dswrf_sfc_0', ylabel='Daily_Production'>

# %%
# Method 1: Using corr() method
correlation = df['tcdc_eatm_0'].corr(df['tcolc_eatm_0'])

print("Correlation between column1 and column2:", correlation)
# Out:
# Correlation between column1 and column2: 0.9999932513156048

# %%
correlation = df['apcp_sfc_0'].corr(df['tcolc_eatm_0'])

print("Correlation between column1 and column2:", correlation)
# Out:
# Correlation between column1 and column2: 0.7413742443781998

# %%
correlation = df['pres_msl_0'].corr(df['tcolc_eatm_0'])

print("Correlation between column1 and column2:", correlation)
# Out:
# Correlation between column1 and column2: -0.06290787064775238

# %%
columns_to_drop = [ 'apcp_sfc_0', 'tcolc_eatm_0','tcdc_eatm_0']

#Drop the specified columns
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.head()
# Out:
#           Unnamed: 0  stid  Daily_Production  \
# Date
# 19940101           0  ACME          12384900
# 19940102           1  ACME          11908500
# 19940103           2  ACME          12470700
# 19940104           3  ACME          12725400
# 19940105           4  ACME          10894800
#
#                                               new_distances  min_dist_node  \
# Date
# 19940101  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940102  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940103  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940104  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19940105  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
#
#                            join  ulwrf_tatm_0  dlwrf_sfc_0  tmp_sfc_0  \
# Date
# 19940101  19940101(35.0, 262.0)     254.38380    258.64188  282.54855
# 19940102  19940102(35.0, 262.0)     231.38722    279.48965  282.33215
# ...

# %%
df.shape
# Out:
# (501074, 18)

# %%
df[(df['dswrf_sfc_0']>400) & (df['Daily_Production']<0.5*10**7)]
# Out:
#           Unnamed: 0  stid  Daily_Production  \
# Date
# 19950410         464  ACME           4367100
# 20020412        3023  ACME           3985800
# 20050827        4256  ACME           3354300
# 20000727        7512  ADAX           4144200
# 20020412        8136  ADAX           4920600
# ...              ...   ...               ...
# 19990524      497930  WYNO            647400
# 19990805      498003  WYNO           3823500
# 20000515      498287  WYNO           4426500
# 20030602      499400  WYNO            393900
# 20060424      500457  WYNO           3767400
#
#                                               new_distances  min_dist_node  \
# Date
# 19950410  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 20020412  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 20050827  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 20000727  {(33.0, 257.0): 617.4406752421336, (33.0, 258....  (35.0, 263.0)
# ...

# %%
sns.scatterplot(x='uswrf_sfc_0',y='Daily_Production',data=df)
# Out:
# <Axes: xlabel='uswrf_sfc_0', ylabel='Daily_Production'>

# %%
df[(df['uswrf_sfc_0']<150) & (df['Daily_Production']>3.0*10**7)]
# Out:
#           Unnamed: 0  stid  Daily_Production  \
# Date
# 19960609         890  ACME          30448200
# 19970510        1225  ACME          30106500
# 19980612        1623  ACME          30191100
# 19980614        1625  ACME          30621900
# 19980616        1627  ACME          30404100
# ...              ...   ...               ...
# 20040624      499788  WYNO          30834300
# 20050620      500149  WYNO          30127200
# 20060608      500502  WYNO          30037800
# 20060614      500508  WYNO          30223200
# 20070608      500867  WYNO          30698400
#
#                                               new_distances  min_dist_node  \
# Date
# 19960609  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19970510  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19980612  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# 19980614  {(33.0, 257.0): 501.30264193302355, (33.0, 258...  (35.0, 262.0)
# ...

# %%
np.percentile(df['Daily_Production'],[75,25])
# Out:
# array([23394000., 10838400.])

# %%
df.corr()['Daily_Production'].sort_values()
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_22508\4203343499.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Daily_Production'].sort_values()
# pres_msl_0         -0.203145
# Unnamed: 0         -0.021058
# pwat_eatm_0         0.224853
# dlwrf_sfc_0         0.327998
# spfh_2m_0           0.395207
# tmin_2m_0           0.564548
# tmp_2m_0            0.612552
# tmax_2m_0           0.612744
# ulwrf_sfc_0         0.623809
# tmp_sfc_0           0.634328
# ulwrf_tatm_0        0.648427
# uswrf_sfc_0         0.783920
# dswrf_sfc_0         0.875885
# Daily_Production    1.000000
# Name: Daily_Production, dtype: float64

# %%
q75,q25 = np.percentile(df['dswrf_sfc_0'],[75,25])

# %%
iqr1 = q75-q25

# %%
iqr1
# Out:
# 236.16362

# %%
q25-1.5*iqr1
# Out:
# -120.13631000000001

# %%
np.percentile(df['uswrf_sfc_0'],[75,25])
# Out:
# array([89.01818 , 50.345455])

# %%
np.percentile(df['ulwrf_tatm_0'],[75,25])
# Out:
# array([280.60617, 235.29022])

# %%
np.percentile(df['tmp_sfc_0'],[75,25])
# Out:
# array([300.2853825, 283.63644  ])

# %%
np.percentile(df['ulwrf_sfc_0'],[75,25])
# Out:
# array([455.6926125, 364.89508  ])

# %%
X = df.drop('Daily_Production',axis=1)

# %%
y = df['Daily_Production']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter = PolynomialFeatures(degree=2,include_bias=False)

# %%
polynomial_converter.fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 polynomial_converter.fit(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_polynomial.py:322, in PolynomialFeatures.fit(self, X, y)
#     304 @_fit_context(prefer_skip_nested_validation=True)
#     305 def fit(self, X, y=None):
#     306     """
#     307     Compute number of output features.
#     308
#    (...)
#     320         Fitted transformer.
#     321     """
# ...

# %%
X1 = df[[ 'ulwrf_tatm_0', 'dlwrf_sfc_0', 'tmp_sfc_0', \
        'dswrf_sfc_0', 'tmax_2m_0', 'tmin_2m_0', 'pwat_eatm_0', \
       'uswrf_sfc_0', 'spfh_2m_0', 'ulwrf_sfc_0', 'tmp_2m_0','pres_msl_0']]

# %%
y1 = df['Daily_Production']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter = PolynomialFeatures(degree=2,include_bias=False)

# %%
poly_features = polynomial_converter.fit_transform(X1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.2, random_state=101)

# %%
X_train.shape
# Out:
# (400859, 90)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train[0]
# Out:
# array([-0.28891441, -2.18492971, -1.85065162, -0.34146561, -1.95542488,
#        -2.01234106, -1.55865029, -0.76178897, -1.4806028 , -1.74315243,
#        -1.98310021,  2.13027708, -0.36980991, -1.63319842, -0.65162006,
#        -0.42161925, -0.66734905, -0.67367624, -1.48895004, -0.75977858,
#        -1.38052466, -1.13606206, -0.6768301 , -0.18353471, -1.86970791,
#        -2.08370223, -1.00121891, -2.09537714, -2.0942029 , -1.34307983,
#        -1.2633737 , -1.33228646, -1.83842731, -2.09503666, -2.16980685,
#        -1.81612719, -0.48026071, -1.86943646, -1.89825339, -1.51786821,
#        -0.86317101, -1.45173244, -1.71121354, -1.88167175, -1.58735092,
#        -0.52874734, -0.48532426, -0.48532507, -1.17242371, -0.72360665,
#        -1.11269466, -0.75753262, -0.48842699, -0.307035  , -1.91777892,
#        -1.94774226, -1.51901421, -0.86925599, -1.45296909, -1.73111729,
#        -1.93109305, -1.70474039, -1.97186923, -1.51744484, -0.87044798,
# ...

# %%
poly_features[0]
# Out:
# array([2.54383800e+02, 2.58641880e+02, 2.82548550e+02, 2.19090910e+02,
#        2.84397060e+02, 2.80260600e+02, 8.08630000e+00, 4.77454500e+01,
#        3.32194400e-03, 3.64319800e+02, 2.82354300e+02, 1.02023780e+05,
#        6.47111177e+04, 6.57943043e+04, 7.18757738e+04, 5.57331782e+04,
#        7.23460048e+04, 7.12937564e+04, 2.05702372e+03, 1.21456690e+04,
#        8.45048738e-01, 9.26770551e+04, 7.18263598e+04, 2.59531968e+07,
#        6.68956221e+04, 7.30788882e+04, 5.66660849e+04, 7.35569903e+04,
#        7.24871285e+04, 2.09145583e+03, 1.23489729e+04, 8.59193841e-01,
#        9.42283580e+04, 7.30286470e+04, 2.63876223e+07, 7.98336831e+04,
#        6.19038189e+04, 8.03559769e+04, 7.91872262e+04, 2.28477234e+03,
#        1.34904077e+04, 9.38610460e-01, 1.02938031e+05, 7.97787981e+04,
#        2.88266711e+07, 4.80008268e+04, 6.23088107e+04, 6.14025499e+04,
#        1.77163483e+03, 1.04605941e+04, 7.27807734e-01, 7.98191565e+04,
# ...

# %%
from sklearn .linear_model import Ridge

# %%
ridge_model = Ridge(alpha=10)

# %%
ridge_model.fit(X_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
test_predictions = ridge_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
MAE = mean_absolute_error(y_test,test_predictions)

# %%
MAE
# Out:
# 2344115.4457920818

# %%
RMSE = np.sqrt(mean_squared_error(y_test,test_predictions))

# %%
RMSE
# Out:
# 3324010.3626728067
